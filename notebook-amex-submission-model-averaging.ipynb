# %% [markdown]
# <a href="https://www.kaggle.com/code/erwanchesneau/notebook-amex-submission-model-averaging?scriptVersionId=104556783" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python librairies

# %%
# LOAD LIBRARIES
import gc
import os
import pickle
import pandas as pd
import numpy as np # CPU libraries
import cudf # GPU libraries
import xgboost as xgb
from catboost import CatBoostClassifier
print('RAPIDS version',cudf.__version__)
# Out:
# RAPIDS version 21.10.01

# %% [markdown]
# # variables

# %%
# VERSION NAME FOR SAVED MODEL FILES
VER = 4

# TRAIN RANDOM SEED
SEED = 42

# FILL NAN VALUE
NAN_VALUE = -127 # will fit in int8

# FOLDS PER MODEL
FOLDS = 5

TRAIN_PATH = '../input/amex-data-integer-dtypes-parquet-format/train.parquet'

TEST_PATH = '../input/amex-data-integer-dtypes-parquet-format/test.parquet'

MODEL_PATH = "../input/amex-outputs-echesneau-lr005"

cat_features = ["B_30", "B_38","D_114","D_116","D_117","D_120","D_126","D_63","D_64","D_66","D_68"]

# %%
len(os.listdir(MODEL_PATH))
# Out:
# 33

# %% [markdown]
# 33 models are saved in the MODEL_PATH.
# The average of the predictions will be calculated

# %% [markdown]
# # functions

# %%
def read_file(path = '', usecols = None):
    """
    function to load dataset
    The function is modified frm the original one
    The Fillna is done only during the processing
    """
    # LOAD DATAFRAME
    if usecols is not None:
        data = cudf.read_parquet(path, columns=usecols)
    else:
        data = cudf.read_parquet(path)
    # REDUCE DTYPE FOR CUSTOMER AND DATE
    data['customer_ID'] = data['customer_ID'].str[-16:].str.hex_to_int().astype('int64')
    data.S_2 = cudf.to_datetime( data.S_2 )
    print('shape of data:', data.shape)

    return data

# %%
def process_and_feature_engineer(data):
    """
    function to process database
    FEATURE ENGINEERING FROM
    https://www.kaggle.com/code/huseyincot/amex-agg-data-how-it-created
    """
    all_cols = [c for c in list(data.columns) if c not in ['customer_ID','S_2']]
    cat_feat = ["B_30","B_38","D_114","D_116","D_117",\
                    "D_120","D_126","D_63","D_64","D_66","D_68"]
    num_features = [col for col in all_cols if col not in cat_feat]

    test_num_agg = data.groupby("customer_ID")[num_features].agg(['mean', \
                                                                  'std', \
                                                                  'min', \
                                                                  'max', \
                                                                  'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]

    test_cat_agg = data.groupby("customer_ID")[cat_feat].agg(['count', \
                                                              'last', \
                                                              'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]

    data = cudf.concat([test_num_agg, test_cat_agg], axis=1)
    del test_num_agg, test_cat_agg
    data = data.fillna(NAN_VALUE)
    return data

# %%
def amex_metric_mod(y_true, y_pred):
    """
    function to calculate the metric of the competion
    from https://www.kaggle.com/kyakovlev
    and https://www.kaggle.com/competitions/amex-default-prediction/discussion/327534
    """
    labels     = np.transpose(np.array([y_true, y_pred]))
    labels     = labels[labels[:, 1].argsort()[::-1]]
    weights    = np.where(labels[:,0]==0, 20, 1)
    cut_vals   = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four   = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])

    gini = [0,0]
    for i in [1,0]:
        labels         = np.transpose(np.array([y_true, y_pred]))
        labels         = labels[labels[:, i].argsort()[::-1]]
        weight         = np.where(labels[:,0]==0, 20, 1)
        weight_random  = np.cumsum(weight / np.sum(weight))
        total_pos      = np.sum(labels[:, 0] *  weight)
        cum_pos_found  = np.cumsum(labels[:, 0] * weight)
        lorentz        = cum_pos_found / total_pos
        gini[i]        = np.sum((lorentz - weight_random) * weight)

    return 0.5 * (gini[1]/gini[0] + top_four)

# %%
def get_rows(cust, data, num_parts = 4, verbose = ''):
    """
    function to split the database
    CALCULATE SIZE OF EACH SEPARATE TEST PART
    """
    chunk = len(cust)//num_parts
    if verbose != '':
        print(f'We will process {verbose} data as {num_parts} separate parts.')
        print(f'There will be {chunk} customers in each part (except the last part).')
        print('Below are number of rows in each part:')
    lrows = []

    for n in range(num_parts):
        if n == num_parts - 1:
            ncust = cust[n*chunk:]
        else:
            ncust = cust[n*chunk:(n+1)*chunk]
        cust_size = data.loc[data.customer_ID.isin(ncust)].shape[0]
        lrows.append(cust_size)
    if verbose != '':
        print( lrows )
    return lrows, chunk

# %% [markdown]
# # load data

# %% [markdown]
# All models do not used the same features.
# They are load from MODEL_PATH

# %%
if os.path.isfile(MODEL_PATH+"/all_features.pkl") :
    with open(MODEL_PATH+"/all_features.pkl", 'rb') as f :
        FEATURES = pickle.load(f)
if os.path.isfile(MODEL_PATH+"/all_features_2.pkl") :
    with open(MODEL_PATH+"/all_features_2.pkl", 'rb') as f :
        FEATURES_2 = pickle.load(f)
if os.path.isfile(MODEL_PATH+"/all_features_3.pkl") :
    with open(MODEL_PATH+"/all_features_3.pkl", 'rb') as f :
        FEATURES_3 = pickle.load(f)

# %% [markdown]
# # Test on train data

# %% [markdown]
# The accuracy is calculated on train set before test set.

# %%
NUM_PARTS = 3
print('Reading train data...')
train = read_file(path = TRAIN_PATH, usecols = ['customer_ID','S_2'])
customers = train[['customer_ID']].drop_duplicates().sort_index().values.flatten()
rows,num_cust = get_rows(customers, train[['customer_ID']], num_parts = NUM_PARTS, verbose = 'test')
# Out:
# Reading train data...
# shape of data: (5531451, 2)
# We will process test data as 3 separate parts.
# There will be 152971 customers in each part (except the last part).
# Below are number of rows in each part:
# [1845301, 1842259, 1843891]

# %%
# INFER Train DATA IN PARTS
SKIP_rows = 0
SKIP_CUST = 0
for k in range(NUM_PARTS):
    # READ PART OF TRAIN DATA
    print('\nReading train data...')
    train = read_file(path = TRAIN_PATH)
    if k == 0 :
        c = train[['customer_ID']].drop_duplicates().sort_index()['customer_ID'].to_pandas()
        result_preds = pd.DataFrame(index=c.to_list())
        del c
        #result_preds = test[['P_2']].to_pandas().copy(deep=True)
        #result_preds = result_preds[['customer_ID']].drop_duplicates().sort_index()
    train = train.iloc[SKIP_ROWS:SKIP_ROWS+rows[k]]
    print(f'=> Train part {k+1} has shape', train.shape )
    print(f"From line {SKIP_ROWS} to {SKIP_ROWS+rows[k]}")
    SKIP_ROWS += rows[k]

    for file in os.listdir(MODEL_PATH) :
        if os.path.isfile(MODEL_PATH+"/"+file) and not file.endswith('.pkl'):
            print(f"Process model : {file}")
            if "_".join(file.split('_')[1:3]) == "all_features" :
                proc = process_and_feature_engineer(train).to_pandas()
                proc = proc[FEATURES]
            elif  "_".join(file.split('_')[1:3]) == "nonan_features" :
                proc = process_and_feature_engineer(train).to_pandas()
                proc = proc[FEATURES_2]
            elif "_".join(file.split('_')[1:3]) == "dc0_features" :
                proc = process_and_feature_engineer(train).to_pandas()
                proc = proc[FEATURES_3]
            else :
                print(f"Unknown preprocessing : {'_'.join(file.split('_')[1:3])}")
            if file.startswith("XGB") :
                tmp = proc[['B_2_max']].copy(deep=True)
                dtest = xgb.DMatrix(data=proc)
                model = xgb.Booster()
                model.load_model(f'{MODEL_PATH}/{file}')
                tmp[f"{file}_parts-{k}"] = model.predict(dtest)
                tmp.drop('B_2_max', axis=1,inplace=True)
                result_preds = result_preds.merge(tmp, left_index=True, \
                                                  right_index=True, how='left')
                del dtest
            elif file.startswith("CTB") :
                tmp = proc[['B_2_max']].copy(deep=True)
                model = CatBoostClassifier()
                model.load_model(f'{MODEL_PATH}/{file}')
                tmp[f"{file}_parts-{k}"] = model.predict_proba(proc)[:,1]
                tmp.drop('B_2_max', axis=1,inplace=True)
                result_preds = result_preds.merge(tmp, left_index=True, \
                                                  right_index=True, how='left')
            else :
                print(f"Unknown model {file}")

            try :
                del proc, model, tmp
                _ = gc.collect()
            except NameError :
                pass
    del train
    _ = gc.collect()
# Out:
# Reading train data...
# shape of data: (5531451, 190)
# => Train part 1 has shape (1845301, 190)
# From line 0 to 1845301
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading train data...
# shape of data: (5531451, 190)
# => Train part 2 has shape (1842259, 190)
# From line 1845301 to 3687560
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading train data...
# shape of data: (5531451, 190)
# => Train part 3 has shape (1843891, 190)
# From line 3687560 to 5531451
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb

# %% [markdown]
# Results are store in a DataFrame.
# Folds are merge into one row.
# Targets are merge.

# %%
results = result_preds.groupby(['_'.join(col.split('_')[:-1]) 
                                for col in result_preds.columns],
                               axis=1).mean()
targets = cudf.read_csv('../input/amex-default-prediction/train_labels.csv')
targets['customer_ID'] = targets['customer_ID'].str[-16:].str.hex_to_int().astype('int64')
targets = targets.set_index('customer_ID')

# %%
results = results.merge(targets.to_pandas(), left_index=True, right_index=True, how='left')

# %% [markdown]
# The AMEX metric is calculated for all models

# %%
amex_metrix = pd.DataFrame(columns=['model', 'amex_metrics'])
for col in [columns for columns in results.columns if columns != 'target']:
    amex_metrix = amex_metrix.append({"model" : col , \
                                      'amex_metrics' : amex_metric_mod(results['target'], \
                                                                       results[col])},
                                    ignore_index=True)
amex_metrix
# Out:
#                               model  amex_metrics
# 0     CTB_all_features_v2_fold0.ctb      0.851374
# 1     CTB_all_features_v2_fold1.ctb      0.841940
# 2     CTB_all_features_v2_fold2.ctb      0.834228
# 3     CTB_all_features_v2_fold3.ctb      0.851709
# 4     CTB_all_features_v2_fold4.ctb      0.848916
# 5     CTB_dc0_features_v2_fold0.ctb      0.846078
# 6     CTB_dc0_features_v2_fold1.ctb      0.846582
# 7     CTB_dc0_features_v2_fold2.ctb      0.839954
# 8     CTB_dc0_features_v2_fold3.ctb      0.834161
# 9     CTB_dc0_features_v2_fold4.ctb      0.843203
# 10  CTB_nonan_features_v2_fold0.ctb      0.853006
# 11  CTB_nonan_features_v2_fold1.ctb      0.848873
# 12  CTB_nonan_features_v2_fold2.ctb      0.840892
# 13  CTB_nonan_features_v2_fold3.ctb      0.829453
# 14  CTB_nonan_features_v2_fold4.ctb      0.842125
# 15    XGB_all_features_v2_fold0.xgb      0.842966
# 16    XGB_all_features_v2_fold1.xgb      0.839152
# 17    XGB_all_features_v2_fold2.xgb      0.843523
# 18    XGB_all_features_v2_fold3.xgb      0.837353
# 19    XGB_all_features_v2_fold4.xgb      0.855474
# 20    XGB_dc0_features_v2_fold0.xgb      0.845540
# 21    XGB_dc0_features_v2_fold1.xgb      0.839020
# 22    XGB_dc0_features_v2_fold2.xgb      0.832377
# 23    XGB_dc0_features_v2_fold3.xgb      0.836892
# 24    XGB_dc0_features_v2_fold4.xgb      0.842041
# 25  XGB_nonan_features_v2_fold0.xgb      0.842235
# 26  XGB_nonan_features_v2_fold1.xgb      0.830645
# 27  XGB_nonan_features_v2_fold2.xgb      0.830035
# 28  XGB_nonan_features_v2_fold3.xgb      0.830897
# 29  XGB_nonan_features_v2_fold4.xgb      0.837238

# %% [markdown]
# No conclusion on the accuracy of models could be done due to a overfitting on the train set.

# %% [markdown]
# # Create submission CSV

# %% [markdown]
# Prediction on the test set and creation of the submission file.

# %%
# COMPUTE SIZE OF 5 PARTS FOR TEST DATA
NUM_PARTS = 5
print('Reading test data...')
test = read_file(path = TEST_PATH, usecols = ['customer_ID','S_2'])
customers = test[['customer_ID']].drop_duplicates().sort_index().values.flatten()
rows,num_cust = get_rows(customers, test[['customer_ID']], num_parts = NUM_PARTS, verbose = 'test')
# Out:
# Reading test data...
# shape of data: (11363762, 2)
# We will process test data as 5 separate parts.
# There will be 184924 customers in each part (except the last part).
# Below are number of rows in each part:
# [2273670, 2271314, 2273248, 2273840, 2271690]

# %% [markdown]
# This part of the code could be modify to use only selection of models.

# %%
# INFER TEST DATA IN PARTS
SKIP_ROWS = 0
SKIP_CUST = 0
#test_preds = []
for k in range(NUM_PARTS):
    # READ PART OF TEST DATA
    print('\nReading test data...')
    test = read_file(path = TEST_PATH)
    if k == 0 :
        c = test[['customer_ID']].drop_duplicates().sort_index()['customer_ID'].to_pandas()
        result_preds = pd.DataFrame(index=c.to_list())
        del c
        #result_preds = test[['P_2']].to_pandas().copy(deep=True)
        #result_preds = result_preds[['customer_ID']].drop_duplicates().sort_index()
    test = test.iloc[SKIP_ROWS:SKIP_ROWS+rows[k]]
    #test = test.to_pandas()
    print(f'=> Test part {k+1} has shape', test.shape )
    print(f"From line {SKIP_ROWS} to {SKIP_ROWS+rows[k]}")
    SKIP_ROWS += rows[k]

    for file in os.listdir(MODEL_PATH) :
        if os.path.isfile(MODEL_PATH+"/"+file) and not file.endswith('.pkl'):
            print(f"Process model : {file}")
            if "_".join(file.split('_')[1:3]) == "all_features" :
                proc = process_and_feature_engineer(test).to_pandas()
                proc = proc[FEATURES]
            elif  "_".join(file.split('_')[1:3]) == "nonan_features" :
                proc = process_and_feature_engineer(test).to_pandas()
                proc = proc[FEATURES_2]
            elif "_".join(file.split('_')[1:3]) == "dc0_features" :
                proc = process_and_feature_engineer(test).to_pandas()
                proc = proc[FEATURES_3]
            else :
                print(f"Unknown preprocessing : {'_'.join(file.split('_')[1:3])}")
            if file.startswith("XGB") :
                tmp = proc[['B_2_max']].copy(deep=True)
                dtest = xgb.DMatrix(data=proc)
                model = xgb.Booster()
                model.load_model(f'{MODEL_PATH}/{file}')
                tmp[f"{file}_parts-{k}"] = model.predict(dtest)
                tmp.drop('B_2_max', axis=1,inplace=True)
                result_preds = result_preds.merge(tmp, left_index=True, \
                                                  right_index=True, how='left')
                del dtest
            elif file.startswith("CTB") :
                tmp = proc[['B_2_max']].copy(deep=True)
                #categ = []
                #for col in proc.columns :
                #    var = '_'.join(col.split('_')[:2])
                #    if var in cat_features :
                #        categ.append(col)
                model = CatBoostClassifier()
                model.load_model(f'{MODEL_PATH}/{file}')
                tmp[f"{file}_parts-{k}"] = model.predict_proba(proc)[:,1]
                tmp.drop('B_2_max', axis=1,inplace=True)
                result_preds = result_preds.merge(tmp, left_index=True, \
                                                  right_index=True, how='left')
            else :
                print(f"Unknown model {file}")

            try :
                del proc, model, tmp
                _ = gc.collect()
            except NameError :
                pass
    del test
    _ = gc.collect()
# Out:
# Reading test data...
# shape of data: (11363762, 190)
# => Test part 1 has shape (2273670, 190)
# From line 0 to 2273670
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading test data...
# shape of data: (11363762, 190)
# => Test part 2 has shape (2271314, 190)
# From line 2273670 to 4544984
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading test data...
# shape of data: (11363762, 190)
# => Test part 3 has shape (2273248, 190)
# From line 4544984 to 6818232
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading test data...
# shape of data: (11363762, 190)
# => Test part 4 has shape (2273840, 190)
# From line 6818232 to 9092072
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb
#
# Reading test data...
# shape of data: (11363762, 190)
# => Test part 5 has shape (2271690, 190)
# From line 9092072 to 11363762
# Process model : XGB_nonan_features_v2_fold2.xgb
# Process model : XGB_dc0_features_v2_fold1.xgb
# Process model : XGB_dc0_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold4.ctb
# Process model : CTB_all_features_v2_fold3.ctb
# Process model : CTB_all_features_v2_fold2.ctb
# Process model : XGB_all_features_v2_fold2.xgb
# Process model : XGB_nonan_features_v2_fold4.xgb
# Process model : XGB_all_features_v2_fold1.xgb
# Process model : CTB_nonan_features_v2_fold4.ctb
# Process model : XGB_dc0_features_v2_fold2.xgb
# Process model : CTB_all_features_v2_fold0.ctb
# Process model : XGB_all_features_v2_fold3.xgb
# Process model : XGB_all_features_v2_fold0.xgb
# Process model : XGB_dc0_features_v2_fold3.xgb
# Process model : XGB_dc0_features_v2_fold4.xgb
# Process model : XGB_nonan_features_v2_fold3.xgb
# Process model : CTB_nonan_features_v2_fold2.ctb
# Process model : CTB_nonan_features_v2_fold0.ctb
# Process model : XGB_nonan_features_v2_fold1.xgb
# Process model : XGB_nonan_features_v2_fold0.xgb
# Process model : CTB_all_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold4.ctb
# Process model : XGB_all_features_v2_fold4.xgb
# Process model : CTB_nonan_features_v2_fold1.ctb
# Process model : CTB_dc0_features_v2_fold2.ctb
# Process model : CTB_dc0_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold1.ctb
# Process model : CTB_nonan_features_v2_fold3.ctb
# Process model : CTB_dc0_features_v2_fold0.ctb

# %% [markdown]
# The final prediction is the mean value of each row.

# %%
pred = result_preds.mean(axis=1).reset_index()
pred.columns = ["customer_ID", "prediction"]
pred
# Out:
#                 customer_ID  prediction
# 0       8717704911770597815    0.024157
# 1       4783907996972277493    0.001554
# 2       4616129756878093544    0.056093
# 3      -1916505587365783916    0.237923
# 4       7583456031722841431    0.835351
# ...                     ...         ...
# 924616  6937247370370204702    0.018715
# 924617 -1095995500929174867    0.719742
# 924618   674735392150270193    0.470156
# 924619  3353833074890263815    0.301515
# 924620 -1477111782539041971    0.071558
#
# [924621 rows x 2 columns]

# %%
result_preds
# Out:
#                       XGB_nonan_features_v2_fold2.xgb_parts-0  \
#  8717704911770597815                                 0.026069
#  4783907996972277493                                 0.001257
#  4616129756878093544                                 0.040507
# -1916505587365783916                                 0.306913
#  7583456031722841431                                 0.895786
# ...                                                       ...
#  6937247370370204702                                      NaN
# -1095995500929174867                                      NaN
#  674735392150270193                                       NaN
#  3353833074890263815                                      NaN
# -1477111782539041971                                      NaN
#
#                       XGB_dc0_features_v2_fold1.xgb_parts-0  \
#  8717704911770597815                               0.020586
#  4783907996972277493                               0.000905
#  4616129756878093544                               0.075919
# -1916505587365783916                               0.267956
#  7583456031722841431                               0.801711
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       XGB_dc0_features_v2_fold0.xgb_parts-0  \
#  8717704911770597815                               0.025547
#  4783907996972277493                               0.000626
#  4616129756878093544                               0.073146
# -1916505587365783916                               0.220687
#  7583456031722841431                               0.801950
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       CTB_all_features_v2_fold4.ctb_parts-0  \
#  8717704911770597815                               0.025651
#  4783907996972277493                               0.002261
#  4616129756878093544                               0.039404
# -1916505587365783916                               0.195803
#  7583456031722841431                               0.859152
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       CTB_all_features_v2_fold3.ctb_parts-0  \
#  8717704911770597815                               0.015572
#  4783907996972277493                               0.001838
#  4616129756878093544                               0.044030
# -1916505587365783916                               0.207401
#  7583456031722841431                               0.761682
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       CTB_all_features_v2_fold2.ctb_parts-0  \
#  8717704911770597815                               0.020418
#  4783907996972277493                               0.002384
#  4616129756878093544                               0.041083
# -1916505587365783916                               0.186689
#  7583456031722841431                               0.853051
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       XGB_all_features_v2_fold2.xgb_parts-0  \
#  8717704911770597815                               0.044298
#  4783907996972277493                               0.001120
#  4616129756878093544                               0.079114
# -1916505587365783916                               0.218940
#  7583456031722841431                               0.855905
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       XGB_nonan_features_v2_fold4.xgb_parts-0  \
#  8717704911770597815                                 0.031882
#  4783907996972277493                                 0.001450
#  4616129756878093544                                 0.052673
# -1916505587365783916                                 0.345282
#  7583456031722841431                                 0.914166
# ...                                                       ...
#  6937247370370204702                                      NaN
# -1095995500929174867                                      NaN
#  674735392150270193                                       NaN
#  3353833074890263815                                      NaN
# -1477111782539041971                                      NaN
#
#                       XGB_all_features_v2_fold1.xgb_parts-0  \
#  8717704911770597815                               0.028241
#  4783907996972277493                               0.001465
#  4616129756878093544                               0.085929
# -1916505587365783916                               0.258040
#  7583456031722841431                               0.883540
# ...                                                     ...
#  6937247370370204702                                    NaN
# -1095995500929174867                                    NaN
#  674735392150270193                                     NaN
#  3353833074890263815                                    NaN
# -1477111782539041971                                    NaN
#
#                       CTB_nonan_features_v2_fold4.ctb_parts-0  ...  \
#  8717704911770597815                                 0.019874  ...
#  4783907996972277493                                 0.002448  ...
#  4616129756878093544                                 0.039683  ...
# -1916505587365783916                                 0.235159  ...
#  7583456031722841431                                 0.781049  ...
# ...                                                       ...  ...
#  6937247370370204702                                      NaN  ...
# -1095995500929174867                                      NaN  ...
#  674735392150270193                                       NaN  ...
#  3353833074890263815                                      NaN  ...
# -1477111782539041971                                      NaN  ...
#
#                       XGB_nonan_features_v2_fold0.xgb_parts-4  \
#  8717704911770597815                                      NaN
#  4783907996972277493                                      NaN
#  4616129756878093544                                      NaN
# -1916505587365783916                                      NaN
#  7583456031722841431                                      NaN
# ...                                                       ...
#  6937247370370204702                                 0.026759
# -1095995500929174867                                 0.687221
#  674735392150270193                                  0.609786
#  3353833074890263815                                 0.241444
# -1477111782539041971                                 0.055106
#
#                       CTB_all_features_v2_fold1.ctb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.015452
# -1095995500929174867                               0.806228
#  674735392150270193                                0.555199
#  3353833074890263815                               0.349678
# -1477111782539041971                               0.070665
#
#                       CTB_dc0_features_v2_fold4.ctb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.013673
# -1095995500929174867                               0.686270
#  674735392150270193                                0.411179
#  3353833074890263815                               0.345387
# -1477111782539041971                               0.073766
#
#                       XGB_all_features_v2_fold4.xgb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.018917
# -1095995500929174867                               0.618067
#  674735392150270193                                0.430565
#  3353833074890263815                               0.353512
# -1477111782539041971                               0.046023
#
#                       CTB_nonan_features_v2_fold1.ctb_parts-4  \
#  8717704911770597815                                      NaN
#  4783907996972277493                                      NaN
#  4616129756878093544                                      NaN
# -1916505587365783916                                      NaN
#  7583456031722841431                                      NaN
# ...                                                       ...
#  6937247370370204702                                 0.020317
# -1095995500929174867                                 0.775143
#  674735392150270193                                  0.563750
#  3353833074890263815                                 0.348834
# -1477111782539041971                                 0.061502
#
#                       CTB_dc0_features_v2_fold2.ctb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.011588
# -1095995500929174867                               0.719412
#  674735392150270193                                0.495155
#  3353833074890263815                               0.322867
# -1477111782539041971                               0.085181
#
#                       CTB_dc0_features_v2_fold3.ctb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.016652
# -1095995500929174867                               0.736931
#  674735392150270193                                0.354207
#  3353833074890263815                               0.385722
# -1477111782539041971                               0.092546
#
#                       CTB_dc0_features_v2_fold1.ctb_parts-4  \
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.013316
# -1095995500929174867                               0.738438
#  674735392150270193                                0.434580
#  3353833074890263815                               0.436038
# -1477111782539041971                               0.068054
#
#                       CTB_nonan_features_v2_fold3.ctb_parts-4  \
#  8717704911770597815                                      NaN
#  4783907996972277493                                      NaN
#  4616129756878093544                                      NaN
# -1916505587365783916                                      NaN
#  7583456031722841431                                      NaN
# ...                                                       ...
#  6937247370370204702                                 0.021791
# -1095995500929174867                                 0.789073
#  674735392150270193                                  0.539831
#  3353833074890263815                                 0.336697
# -1477111782539041971                                 0.068904
#
#                       CTB_dc0_features_v2_fold0.ctb_parts-4
#  8717704911770597815                                    NaN
#  4783907996972277493                                    NaN
#  4616129756878093544                                    NaN
# -1916505587365783916                                    NaN
#  7583456031722841431                                    NaN
# ...                                                     ...
#  6937247370370204702                               0.015943
# -1095995500929174867                               0.673893
#  674735392150270193                                0.368891
#  3353833074890263815                               0.268115
# -1477111782539041971                               0.070737
#
# [924621 rows x 150 columns]

# %% [markdown]
# A DataFrame is created on the expected format and saved.

# %%
sub = cudf.read_csv('../input/amex-default-prediction/sample_submission.csv')[['customer_ID']]
sub['customer_ID_hash'] = sub['customer_ID'].str[-16:].str.hex_to_int().astype('int64')
sub = sub.set_index('customer_ID_hash').to_pandas()
tmp = pred.set_index("customer_ID")
sub = sub.merge(tmp[['prediction']], left_index=True, right_index=True, how='left')
sub = sub.reset_index(drop=True)
sub.head()
# Out:
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.024157
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.001554
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.056093
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.237923
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.835351

# %%
sub.to_csv(f'submission_xgb_v{VER}.csv',index=False)
print('Submission file shape is', sub.shape )
# Out:
# Submission file shape is (924621, 2)
